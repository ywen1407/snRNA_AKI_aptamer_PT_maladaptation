# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone https://github.com/broadinstitute/CellBender.git
# Out:
# Cloning into 'CellBender'...
# remote: Enumerating objects: 2649, done.
# remote: Counting objects: 100% (388/388), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 2649 (delta 188), reused 359 (delta 176), pack-reused 2261
# Receiving objects: 100% (2649/2649), 28.82 MiB | 31.29 MiB/s, done.
# Resolving deltas: 100% (1573/1573), done.

# %%
# !pip install folium==0.2.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 69 kB 5.3 MB/s
# ...
#   Created wheel for folium: filename=folium-0.2.1-py3-none-any.whl size=79808 sha256=d48ced98e2ca95de26e8886152535f10a19bb83451614213a58eedcdf084af75
#   Stored in directory: /root/.cache/pip/wheels/9a/f0/3a/3f79a6914ff5affaf50cabad60c9f4d565283283c97f0bdccf
# Successfully built folium
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# ...

# %%
# !pip install -e CellBender
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/CellBender
# ...
#      |████████████████████████████████| 96 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 718 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 73.7 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 65.6 MB/s
# ...
#      |████████████████████████████████| 100 kB 13.1 MB/s
# ...
#      |████████████████████████████████| 84 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 90 kB 11.1 MB/s
# ...
#      |████████████████████████████████| 121 kB 57.9 MB/s
# ...
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
#   Running setup.py develop for cellbender
# ...

# %%
mv /content/drive/MyDrive/KPMP/snRNA/snRNA05.2021/AKI/cov_02_0010/cellranger_v7/raw_feature_bc_matrix.h5 .

# %%
# !cellbender remove-background \
                 --input raw_feature_bc_matrix.h5 \
                 --output output.h5 \
                 --expected-cells 6000 \
                 --cuda \
                 --total-droplets-included 20000 \
                 --fpr 0.01 \
                 --epochs 150
# Out:
# cellbender:remove-background: Command:
# cellbender remove-background --input raw_feature_bc_matrix.h5 --output output.h5 --expected-cells 6000 --cuda --total-droplets-included 20000 --fpr 0.01 --epochs 150
# cellbender:remove-background: 2022-06-26 13:55:18
# cellbender:remove-background: Running remove-background
# cellbender:remove-background: Loading data from file raw_feature_bc_matrix.h5
# cellbender:remove-background: CellRanger v3 format
# cellbender:remove-background: Trimming dataset for inference.
# cellbender:remove-background: Including 31403 genes that have nonzero counts.
# cellbender:remove-background: Prior on counts in empty droplets is 364
# cellbender:remove-background: Prior on counts for cells is 3858
# cellbender:remove-background: Excluding barcodes with counts below 182
# cellbender:remove-background: Using 6000 probable cell barcodes, plus an additional 14000 barcodes, and 58203 empty droplets.
# ...

# %%
mv output_filtered.h5 output.h5 output_cell_barcodes.csv output.pdf output.log /content/drive/MyDrive/KPMP/snRNA/snRNA05.2021/AKI/cov_02_0010/cellranger_v7/cellbender/

# %%
mv raw_feature_bc_matrix.h5 /content/drive/MyDrive/KPMP/snRNA/snRNA05.2021/AKI/cov_02_0010/cellranger_v7/
