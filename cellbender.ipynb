# %%
# !git clone https://github.com/broadinstitute/CellBender.git
# Out:
# Cloning into 'CellBender'...
# remote: Enumerating objects: 2466, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 2466 (delta 100), reused 139 (delta 66), pack-reused 2261
# Receiving objects: 100% (2466/2466), 28.64 MiB | 37.94 MiB/s, done.
# Resolving deltas: 100% (1485/1485), done.

# %%
# !pip install -e CellBender --quiet

# %%
# !python generate_tiny_10x_pbmc.py
# Out:
# python3: can't open file 'generate_tiny_10x_pbmc.py': [Errno 2] No such file or directory

# %%
#change directory to folder. using unfiltered output.

# %%
# !ls
# Out:
# barcodes.tsv.gz  features.tsv.gz  matrix.mtx.gz

# %%
# !cellbender remove-background \
     --input ./matrix.mtx.gz \
     --output ./matrix.h5 \
     --expected-cells 11000 \ #expected cell count from filtered output. 
     --total-droplets-included 50000
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 568, in _build_master
#     ws.require(__requires__)
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 886, in require
#     needed = self.resolve(parse_requirements(requirements))
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 777, in resolve
#     raise VersionConflict(dist, req).with_context(dependent_req)
# pkg_resources.ContextualVersionConflict: (docutils 0.17.1 (/usr/local/lib/python3.7/dist-packages), Requirement.parse('docutils<0.17'), {'sphinx-rtd-theme'})
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/cellbender", line 33, in <module>
#     sys.exit(load_entry_point('cellbender', 'console_scripts', 'cellbender')())
#   File "/content/CellBender/cellbender/base_cli.py", line 91, in main
# ...
